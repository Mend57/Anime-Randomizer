# %% [markdown]
# <a href="https://colab.research.google.com/github/Mend57/Anime-Randomizer/blob/main/MAL_Randomizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

uri = "https://raw.githubusercontent.com/teste7/aaa/main/animelist_1602947944_-_7416751.csv"
animes = pd.read_csv(uri)
animes.head()
# Out:
#    series_animedb_id                                series_title series_type  \
# 0               6408                      "Bungaku Shoujo" Movie       Movie
# 1              41380  100-man no Inochi no Ue ni Ore wa Tatteiru          TV
# 2              40679         2.43: Seiin Koukou Danshi Volley-bu          TV
# 3              40148                                        22/7          TV
# 4              31646                             3-gatsu no Lion          TV
#
#    series_episodes  my_id  my_watched_episodes my_start_date my_finish_date  \
# 0                1      0                    0    0000-00-00     0000-00-00
# 1               12      0                    0    0000-00-00     0000-00-00
# 2                0      0                    0    0000-00-00     0000-00-00
# 3               12      0                    0    0000-00-00     0000-00-00
# 4               22      0                    0    0000-00-00     0000-00-00
#
# ...

# %%
animes.query('my_status == "Plan to Watch"', inplace = True)
animes.sample()
# Out:
#     series_animedb_id series_title series_type  series_episodes  my_id  \
# 93               2167      Clannad          TV               23      0
#
#     my_watched_episodes my_start_date my_finish_date  my_rated  my_score  ...  \
# 93                    0    0000-00-00     0000-00-00       NaN         0  ...
#
#     my_comments  my_times_watched my_rewatch_value  my_priority  my_tags  \
# 93          NaN                 0              NaN          LOW      NaN
#
#     my_rewatching my_rewatching_ep  my_discuss   my_sns  update_on_import
# 93              0                0           1  default                 0
#
# [1 rows x 23 columns]
